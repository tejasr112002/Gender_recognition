# %%
import image as im
import cv2
from show_pred import show_prediction
from initialsation import *
SEED = 42
IMG_SIZE = 256
# set seed for reproducibility
set_seed(SEED)
turn_off_warnings()

preprocessing = DataPreprocessing(DATA_PATH, n_max=5, new_size=(IMG_SIZE, IMG_SIZE))
df, stats = preprocessing.get_summary_stats()
datsets = preprocessing.get_cv_splits()

# %%
tf.keras.utils.plot_model(
    models["CNN multitask"],
    to_file="model.png",
    rankdir="LR",
    show_shapes=False,
    show_dtype=False,
    show_layer_names=False,
)

# %%
model_transfer = tf.keras.models.load_model('./Models/Transfer')

# %%
image_path = './tejas_img2.jpg'
img=plt.imread(image_path)

# %%
img_resized=cv2.resize(img,(256,256))
plt.imshow(img_resized)
img_resized=np.expand_dims(img_resized,axis=0)

# %%
model_transfer.predict(img_resized)
# Out:
# 1/1 [==============================] - 0s 185ms/step
# [array([[0.01373321]], dtype=float32),
#  array([[8.5333852e-08, 5.1510651e-06, 1.4463546e-03, 2.6294596e-02,
#          8.3758694e-01, 1.3345574e-01, 1.1723894e-03, 3.8721035e-05]],
#        dtype=float32)]

# %%
show_prediction(img,model_transfer)
# Out:
# 1/1 [==============================] - 0s 426ms/step

# %%
image_path = './mads_img.jpeg'
img=plt.imread(image_path)
show_prediction(img,model_transfer)
# Out:
# 1/1 [==============================] - 0s 70ms/step

# %%
image_path = './kasper_img.jpeg'
img=plt.imread(image_path)
show_prediction(img,model_transfer)
# Out:
# 1/1 [==============================] - 0s 72ms/step

# %%
image_path = './margot_robbie.jpg'
img=plt.imread(image_path)
show_prediction(img,model_transfer)
# Out:
# 1/1 [==============================] - 0s 80ms/step

# %%
image_path = './old.jpg'
img=plt.imread(image_path)
show_prediction(img,model_transfer)
# Out:
# 1/1 [==============================] - 0s 74ms/step

# %%
image_path = './IMG_1161.jpg'
img=plt.imread(image_path)
show_prediction(img,model_transfer)
# Out:
# 1/1 [==============================] - 0s 88ms/step
